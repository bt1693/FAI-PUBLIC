# %% [markdown]
# <a href="https://colab.research.google.com/github/bt1693/FAI-PUBLIC/blob/develop-aug9/FIS_AUG31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %%
data= pd.Series([.25,.5,.75,1.0]) # panda series with  default integer index
print(data)
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data= pd.Series([.25,.5,.75,1.0], index=['a','b','c','d']) # panda series with non-integer index
print(data)
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
print(data['a'])
# Out:
# 0.25

# %%
data={'Kerala':395, 'Goa':400, 'Assam':459}
pop=pd.Series(data)
print(pop)
# Out:
# Kerala    395
# Goa       400
# Assam     459
# dtype: int64

# %%
data={'Fruit':['Apple','Banana','Orange'],'Weight':[200,100,300],'Price':[90,40,100]}
df=pd.DataFrame(data)
print(df)
s1=df.head(2)
print(s1)
s1=df.tail(2)
print(s1)
print(df.loc[0])
df2=pd.DataFrame(data,columns=['Fruit','Weight','Price','Kind'])
print(df2)
df2['Kind']=pd.Series(['K1','K2'])
print(df2)
df2['Kind']=pd.Series(['K1','K2','k3'])
print(df2)
df2['Cost']= df2.Price> 60
print(df2)

del df2['Cost']
print(df2)
# Out:
#     Fruit  Weight  Price
# 0   Apple     200     90
# 1  Banana     100     40
# 2  Orange     300    100
#     Fruit  Weight  Price
# 0   Apple     200     90
# 1  Banana     100     40
#     Fruit  Weight  Price
# 1  Banana     100     40
# 2  Orange     300    100
# Fruit     Apple
# Weight      200
# Price        90
# Name: 0, dtype: object
#     Fruit  Weight  Price Kind
# 0   Apple     200     90  NaN
# 1  Banana     100     40  NaN
# 2  Orange     300    100  NaN
#     Fruit  Weight  Price Kind
# 0   Apple     200     90   K1
# 1  Banana     100     40   K2
# 2  Orange     300    100  NaN
#     Fruit  Weight  Price Kind
# 0   Apple     200     90   K1
# 1  Banana     100     40   K2
# 2  Orange     300    100   k3
#     Fruit  Weight  Price Kind   Cost
# 0   Apple     200     90   K1   True
# 1  Banana     100     40   K2  False
# 2  Orange     300    100   k3   True
#     Fruit  Weight  Price Kind
# 0   Apple     200     90   K1
# 1  Banana     100     40   K2
# ...

# %%
df=pd.read_csv('/content/StudentsPerformance.csv')
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df.head(5))
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
rows,columns=df.shape
print('rows=' , rows ,'columns=',columns)
print(df.info())
print(df.columns)
# Out:
# rows= 1000 columns= 8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
print(list(df.columns))
print(df.dtypes)
# Out:
# ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
print('Mean\n',df.mean(numeric_only=True))
print('Min\n',df.min(numeric_only=True))
print('Max\n',df.max(numeric_only=True))
# Out:
# Mean
#  math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64
# Min
#  math score        0
# reading score    17
# writing score    10
# dtype: int64
# Max
#  math score       100
# reading score    100
# writing score    100
# dtype: int64

# %%
df2= (df['math score'])
print(df2)
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df2= (df[['reading score','writing score']])
print(df2)
# Out:
#      reading score  writing score
# 0               72             74
# 1               90             88
# 2               95             93
# 3               57             44
# 4               78             75
# ..             ...            ...
# 995             99             95
# 996             55             55
# 997             71             65
# 998             78             77
# 999             86             86
#
# [1000 rows x 2 columns]

# %%
df2= (df[['math score','reading score','writing score']]).head(10)
print(df2)
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75
# 5          71             83             78
# 6          88             95             92
# 7          40             43             39
# 8          64             64             67
# 9          38             60             50

# %%
df2= df[df['math score']>80]
print(df2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 981    male        group D            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df2=df[(df['reading score']>70) & (df['writing score']>70)]
print(df2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df2=df[(df['gender']=='female') & (df['math score']>90)]
print(df2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 501  female        group B          associate's degree      standard
# 503  female        group E          associate's degree      standard
# 521  female        group C          associate's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 685  female        group E             master's degree      standard
# ...

# %%
df2=df[(df['test preparation course']=='completed') & (df['reading score']>80)]
print(df2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 35     male        group E          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# 49     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print('average of Math score',df['math score'].mean())
print('Max of writing score',df['writing score'].max())
# Out:
# average of Math score 66.089
# Max of writing score 100

# %%
print('Min of reading score',df['reading score'].min())
# Out:
# Min of reading score 17

# %%
df2= df.groupby

# %%
import matplotlib.pyplot as plt

df2=df.head(1)
print(df2)
# Create a bar chart of the scores for the first student
scores = df2[['math score', 'reading score', 'writing score']].iloc[0]
scores.plot(kind='bar',color='red')
plt.xlabel('Subject')
plt.title('First Student Performance')
plt.ylabel('Score')
plt.xticks(rotation=0)
plt.ylim(0,80)
plt.show()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
