# %% [markdown]
# <a href="https://colab.research.google.com/github/bt1693/FAI-PUBLIC/blob/develop-aug9/Python_basics_1_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
print('''Hello
world ..............''')
# Out:
# Hello
# world ..............

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate a sample image (a gradient)
image = np.linspace(0, 1, 256 * 256).reshape((256, 256))

# Display the image
plt.imshow(image, cmap='gray')
plt.title("Sample Image")
plt.axis('off') # Hide axes
plt.show()

# %%
print(HELLO WORLD)
# Out:
#   File "/tmp/ipython-input-3560297028.py", line 1
#     print(HELLO WORLD)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x=0
print(x)
x=100
print(x)
x=-10
print(x)
x=0
print(x)
x=1234567890
print(x)
x=0190
print(x)
# Out:
#   File "/tmp/ipython-input-1052618321.py", line 11
#     x=0190
#       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
x=0
print(x)
x=100
print(x)
x=-10
print(x)
x=0
print(x)
x=1234567890
print(x)
x=190+2j
print(x)
# Out:
# 0
# 100
# -10
# 0
# 1234567890
# (190+2j)

# %%
x=0
print(type(x))
a=2
b=3
c=a+b
print(c)
# Out:
# <class 'int'>
# 5

# %%
b=0b11011101
print(b)
c=0o76
print(c)
d=0xA
print(d)
# Out:
# 221
# 62
# 10

# %%
b=0xA
c=0xF
d=b+c
print(d)
# Out:
# 25

# %%
x='123'
print(type(x))
# Out:
# <class 'str'>

# %%
x=-10
print(type(x))
y=-10.8
print(type(y))
print(type(x+y))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
x='123'
print(type(x))
y=float(x)
print(y)
print(type(y))
# Out:
# <class 'str'>
# 123.0
# <class 'float'>

# %%
a=1
b=2
c=a<b
print(c)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
a=int(True)
print(a)
# Out:
# 1

# %%
a=("10"+"01")
print(a)
print(type(a))
a=int("10"+"02")
print(a)
print(type(a))
a=float(True)
print(a)
# Out:
# 1001
# <class 'str'>
# 1002
# <class 'int'>
# 1.0

# %%
print(type(True))
print(type(False))
a=1
b=2
c=a<b
print(c)
print(type(c))
# Out:
# <class 'bool'>
# <class 'bool'>
# True
# <class 'bool'>

# %%
dept='Engineereing dept'
print(len(dept))
pos=dept.find('E',7,9)
print(pos)
pos=dept.find('e',7,9)
print(pos)
pos=dept.split()
print(pos)
print(dept[:4])
print(dept[2:4])
print(dept[-8:-4])
print(dept[::-1])
print(dept[-1::])
# Out:
# 17
# -1
# 8
# ['Engineereing', 'dept']
# Engi
# gi
# ing
# tped gniereenignE
# t
