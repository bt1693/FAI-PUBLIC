# %% [markdown]
# <a href="https://colab.research.google.com/github/bt1693/FAI-PUBLIC/blob/develop-aug9/python_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inp= int(input('Enter a number\n'))# sum of current no and prev. no
i=2*inp-1
print(i)
# Out:
# Enter a number
# 5
# 9

# %%
length=int(input('Enter the length\n')) #check if first no and last no are same
a=[]
for i in range(0,length):
  v=int(input('Enter the number\n'))
  a.append(v)
print(a[0]==a[-1])
# Out:
# Enter the length
# 3
# Enter the number
# 5
# Enter the number
# 6
# Enter the number
# 7
# False

# %%
length=int(input('Enter the range\n')) #display no divisible by 5
a=[]
for i in range(1,length+1):
  if i%5==0:
    print(i)
# Out:
# Enter the range
# 10
# 5
# 10

# %%
a=int(input('Enter a number \n'))#factorial
b=1
for i in range(1,a+1):
  b=b*i

print(b)
# Out:
# Enter a number
# 5
# 120

# %%
inp= int(input('Enter a number\n')) #print a pattern
for i in range(1,inp+1):
   print(*i*(str(i),),sep=" ")
# Out:
# Enter a number
# 4
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
list_sam=[1,2,3] # list to set conversion
print(type(list_sam))
list_sam2=set(list_sam)
print(type(list_sam2))
# Out:
# <class 'list'>
# <class 'set'>

# %%
inp= int(input('Enter a number to check its palindrome\n')) # palindrome
if inp==int(str(inp)[::-1]):
  print('Given number is palindrome')
else:
  print('Given number is not a palindrome')
# Out:
# Enter a number to check its palindrome
# 543
# Given number is not a palindrome

# %%
import numpy as np  #sum and average of a list

sam_list=[1,2,3,4,5]
ls=len(sam_list)
c=np.sum(sam_list)
print(c)
print(np.average(sam_list))
# Out:
# 15
# 3.0

# %%
ls=[1,2,3,4] #reverse a list
new_ls=ls[::-1]
print(new_ls)
ls.reverse()
print(ls)
# Out:
# [4, 3, 2, 1]
# [4, 3, 2, 1]

# %%
length=int(input('Enter the length\n')) # replace number with its squares in a list
a=[]
for i in range(0,length):
  v=int(input('Enter the number\n'))
  a.append(v)

for i in range(0,length):
  j=a[i]*a[i]
  a[i]=j

print(a)
# Out:
# Enter the length
# 4
# Enter the number
# 5
# Enter the number
# 6
# Enter the number
# 7
# Enter the number
# 8
# [25, 36, 49, 64]

# %%
d1={"name":"bala","age":30} #merge the dictionaries
d2={"k1":1,"k2":4}
d3= {**d1,**d2}
print(d3)
d3= d1|d2
print(d3)
# Out:
# {'name': 'bala', 'age': 30, 'k1': 1, 'k2': 4}
# {'name': 'bala', 'age': 30, 'k1': 1, 'k2': 4}

# %%
d1={"name":"bala","age":30,"profession":"software"} #create a dict from this
d2=["name","age"] # filtering keys
d3 = {key: d1[key] for key in d1 if key in d2}

print(d3)
# Out:
# {'name': 'bala', 'age': 30}

# %%
s1={1,2,3}
s2={4,5,6,2}
s3=s1.intersection(s2) #intersection of set
print(s3)
s3=s1&(s2)
print(s3)
# Out:
# {2}
# {2}

# %%
lst=[1,2,3,4] #convert list into set

def conv(ls: list):
 print(type(lst))
 st=set(ls)
 print((st))

conv(lst)
# Out:
# <class 'list'>
# {1, 2, 3, 4}

# %%
tup=(1,2,3,4)# reverse a tuple; tuple is immmutable hence new tuple needs to be created with reversed format
tup1=tup[::-1]
print(tup1)
# Out:
# (4, 3, 2, 1)

# %%
t1=(1,2,3,4)#swap the tuple
t2=(5,6,7)
print("before swap")
print("t1",t1)
print("t1",t2)
t1,t2=t2,t1
print("after swap")
print("t1",t1)
print("t1",t2)
# Out:
# before swap
# t1 (1, 2, 3, 4)
# t1 (5, 6, 7)
# after swap
# t1 (5, 6, 7)
# t1 (1, 2, 3, 4)

# %%
ls=[10,20,30] #convert list into tuple
t1=tuple(ls)
t1
# Out:
# (10, 20, 30)

# %%
length=int(input('Enter the length\n')) #create a tuple with unique elements
a=set()
for i in range(0,length):
  v=int(input('Enter the number\n'))
  a.add(v)

t1=tuple((a))
t1
# Out:
# Enter the length
# 3
# Enter the number
# 1
# Enter the number
# 1
# Enter the number
# 2
# (1, 2)

# %%
ls=["apple","orange","papaya"] #list creation ,access elements, modify ,iterate and length
print(ls[0])
print(ls[1])
ls.append("guava")
print(ls)
ls[2]="grapes"
print(ls)
for c in ls:
  print(c)

print(len(ls))
print("papaya" in ls)
print("grapes" in ls)
# Out:
# apple
# orange
# ['apple', 'orange', 'papaya', 'guava']
# ['apple', 'orange', 'grapes', 'guava']
# apple
# orange
# grapes
# guava
# 4
# False
# True
