# %% [markdown]
# <a href="https://colab.research.google.com/github/bt1693/FAI-PUBLIC/blob/develop-aug9/python_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inp= int(input('Enter a number\n'))
i=2*inp-1
print(i)
# Out:
# Enter a number
# 5
# 9

# %%
length=int(input('Enter the length\n'))
a=[]
for i in range(0,length):
  v=int(input('Enter the number\n'))
  a.append(v)
print(a[0]==a[-1])
print(a[::-1])
# Out:
# Enter the length
# 3
# Enter the number
# 1
# Enter the number
# 2
# Enter the number
# 3
# False
# [3, 2, 1]

# %%
length=int(input('Enter the range\n'))
a=[]
for i in range(1,length+1):
  if i%5==0:
    print(i)
# Out:
# Enter the range
# 10
# 5
# 10

# %%
a=int(input('Enter a number \n'))
b=1
for i in range(1,a+1):
  b=b*i

print(b)
# Out:
# Enter a number
# 5
# 120

# %%
inp= int(input('Enter a number\n'))
for i in range(1,inp+1):
   print(*i*(str(i),),sep=" ")
# Out:
# Enter a number
# 4
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
list_sam=[1,2,3]
print(type(list_sam))
list_sam2=set(list_sam)
print(type(list_sam2))
# Out:
# <class 'list'>
# <class 'set'>

# %%
inp= int(input('Enter a number to check its palindrome\n'))
if inp==int(str(inp)[::-1]):
  print('Given number is palindrome')
else:
  print('Given number is not a palindrome')
# Out:
# Enter a number to check its palindrome
# 543
# Given number is not a palindrome

# %%
import numpy as np

sam_list=[1,2,3,4,5]
ls=len(sam_list)
c=np.sum(sam_list)
print(c)
print(np.average(sam_list))
# Out:
# 15
# 3.0
